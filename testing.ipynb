# %% [markdown]
# This PAGE IS FOR MY ROUGH WORK AND UNDERSTANDING THE VALUES IN DETAILS YOU CAN IGNORE IT.

# %%
import pandas as pd
import numpy as np
from openai import OpenAI
import json

# %%
dataset = pd.read_csv('news_dataset.csv')

# %%
dataset = dataset.to_dict(orient="records")

# %%
type(dataset)
# Out:
# list

# %%
print(dataset)
# Out:
# [{'guid': 'e3dc5caa18f9a16d7edcc09f8d5c2bb4', 'title': "Harvey Weinstein's 2020 rape conviction overturned", 'description': 'Victims group describes the New York appeal court\'s decision to retry Hollywood mogul as "profoundly unjust".', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-us-canada-68899382', 'published_at': '2024-04-25 18:24:04+00', 'updated_at': '2024-04-26 20:03:00.628113+00'}, {'guid': '297b7152cd95e80dd200a8e1997e10d9', 'title': 'Police and activists clash on Atlanta campus amid Gaza protests', 'description': 'Meanwhile, hundreds of students march in Washington DC, and congresswoman Ilhan Omar joins protesters at a New York campus.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/live/world-us-canada-68898923', 'published_at': '2024-04-25 13:40:25+00', 'updated_at': '2024-04-26 20:03:00.654819+00'}, {'guid': '170bd18d1635c44b9339bdbaf1e62123', 'title': 'Haiti PM resigns as transitional council sworn in', 'description': 'The council will try to restore order and form a new government in the nation gripped by gang violence.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-latin-america-68896323', 'published_at': '2024-04-25 18:11:02+00', 'updated_at': '2024-04-26 20:03:00.663393+00'}, {'guid': 'e696224ac208878a5cec8bdc9f97c632', 'title': 'Europe risks dying and faces big decisions - Macron', 'description': 'The French president delivers a stark warning for Europe to act fast to survive in a changing world.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-europe-68898887', 'published_at': '2024-04-25 14:51:15+00', 'updated_at': '2024-04-26 20:03:00.672106+00'}, {'guid': '733f744b006fb13033d264efcaf8edad', 'title': "Prosecutors ask for halt to case against Spain PM's wife", 'description': 'Pedro Sánchez is deciding whether to resign after a case against his wife by an anti-corruption group.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-europe-68895727', 'published_at': '2024-04-25 13:07:42+00', 'updated_at': '2024-04-26 20:03:00.682205+00'}, {'guid': '18ba9f2676859f393a271d15692a9c6e', 'title': 'WATCH: Would you pay a tourist fee to enter Venice?', 'description': 'From Thursday visitors making a trip to the famous city at peak times will be charged a trial entrance fee.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-europe-68898441', 'published_at': '2024-04-25 12:26:48+00', 'updated_at': '2024-04-26 20:03:00.690849+00'}, {'guid': '4f585bad8f61b715fbafe2f022ab0ae8', 'title': 'Supreme Court divided on whether Trump has immunity', 'description': 'The justices discussed immunity, coups, pardons, Operation Mongoose - and the future of democracy.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-us-canada-68901817', 'published_at': '2024-04-25 21:02:44+00', 'updated_at': '2024-04-26 20:03:00.704483+00'}, {'guid': '1efb5107e3267f3222932aa8340d9700', 'title': 'More than 150 killed as heavy rains pound Tanzania', 'description': 'The prime minister warns that El Niño-triggered heavy rains are likely to continue into May.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-africa-68896454', 'published_at': '2024-04-25 16:27:14+00', 'updated_at': '2024-04-26 20:03:00.713303+00'}, {'guid': '0159cb36450aa273b256a85e5f4166a1', 'title': "Playboy model's interview 'aggravated' Trump, court hears", 'description': "A tabloid publisher testifies the then-president didn't understand why he let Karen McDougal speak to media.", 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/live/world-us-canada-68894356', 'published_at': '2024-04-25 12:38:00+00', 'updated_at': '2024-04-26 20:03:00.723912+00'}, {'guid': '5dae28f191cfd1047f67c409e616fc3f', 'title': "Paris's Moulin Rouge loses windmill sails overnight", 'description': "The cause of the sails' collapse from the roof of the world famous cabaret club is not yet clear.", 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-europe-68895836', 'published_at': '2024-04-25 10:45:37+00', 'updated_at': '2024-04-26 20: ...

# %%
result=[]
for i in range(0,100):
    result.append(dataset[i])

# %%
with open ("data.json" ,"w") as file:
    json.dump(result,file,indent=4)

# %%
import bm25s
import data_filteration
dataset= data_filteration.data_load()

# %%
filtered_data=[]
for data in dataset:
    filtered_data.append(data['title'])

# %%
tokenized_data = bm25s.tokenize(filtered_data)

# %%
retrieval = bm25s.BM25()
retrieval.index(tokenized_data)

# %%
query="What happened to Ariel Henry and the government of Haiti?"
tokenized_query = bm25s.tokenize(query)

# %%
result,scores = retrieval.retrieve(
    tokenized_query,
    k=5
)

# %%
print(result,scores)
# Out:
# [[ 61 260 154 814   2]] [[6.803364  4.7488    4.647232  2.5052707 2.4097948]]

# %%
for i in range (0,len(result[0])):
    print(dataset[result[0][i]])
# Out:
# {'guid': '072176aad448612370ba30750abf52f9', 'title': "Ariel Henry resigns as Haiti's PM as transitional council takes power", 'description': 'Ariel Henry resigned Thursday as prime minister of Haiti, leaving the way clear for a new government to be formed in the Caribbean country, which has been wracked by gang violence that killed or injured more than 2,500 people from January to March.', 'venue': 'France24', 'url': 'https://www.france24.com/en/americas/20240425-ariel-henry-resigns-as-haiti-s-pm-as-transitional-council-takes-power', 'published_at': '2024-04-25 14:52:35+00', 'updated_at': '2024-04-26 20:03:01.162427+00'}
# {'guid': 'c9c7840abe76f140036562cde383c894', 'title': 'Haitian Prime Minister Ariel Henry resigns; transitional council sworn in', 'description': 'Interim replacement Michel Patrick Boisvert is to work with a transitional council to accept a Kenyan-led U.N. security force and lead the country to a new vote.', 'venue': 'Washington Post', 'url': 'https://www.washingtonpost.com/world/2024/04/25/haiti-ariel-henry-resigns/', 'published_at': '2024-04-25 19:28:46+00', 'updated_at': '2024-04-26 20:03:03.373519+00'}
# {'guid': '2ffb13c7a21437111c6b483ef48368ca', 'title': 'New Haiti government sworn in during secret ceremony', 'description': '‘Transitional council’ takes oath of office after prime minister formally resigns as gang violence continues to rock capitalHaiti’s prime minister, Ariel Henry, has formally resigned and a new provisional government has been sworn in during a secret ceremony at the presidential palace, nearly two months after a criminal insurrection plunged the capital into chaos.The nine-person “transitional council” was officially established on Thursday during an event at the national palace in Port-au-Prince. As its members took their oaths, Henry, who is in the US having been locked out of Haiti by the gang uprising, announced in a letter that he was stepping down. Continue reading...', 'venue': 'The Guardian', 'url': 'https://www.theguardian.com/world/2024/apr/25/new-haiti-government-sworn-in-during-secret-ceremony', 'published_at': '2024-04-25 16:18:52+00', 'updated_at': '2024-04-26 20:03:02.123519+00'}
# {'guid': '37cff9387cc2f57f175fb11dc1ec06b7', 'title': 'US lawmakers approve more government spying', 'description': 'US Senate approves bill extending surveillance law without requiring warrants to spy on American citizens Read Full Article at RT.com', 'venue': 'RT', 'url': 'https://www.rt.com/news/596317-senate-approves-spying-program-renewal/?utm_source=rss&utm_medium=rss&utm_campaign=RSS', 'published_at': '2024-04-20 18:27:43+00', 'updated_at': '2024-04-26 10:32:36.966573+00'}
# {'guid': '170bd18d1635c44b9339bdbaf1e62123', 'title': 'Haiti PM resigns as transitional council sworn in', 'description': 'The council will try to restore order and form a new government in the nation gripped by gang violence.', 'venue': 'BBC', 'url': 'https://www.bbc.co.uk/news/world-latin-america-68896323', 'published_at': '2024-04-25 18:11:02+00', 'updated_at': '2024-04-26 20:03:00.663393+00'}

# %%
print(result[0])
# Out:
# [ 61 260 154 814   2]

# %%
from openai import OpenAI
import data_filteration

# %%
dataset= data_filteration.data_load()
filtered_data_title=[]
for word in dataset:
    filtered_data_title.append(word['title'])

# %%
print(len(dataset))
print(len(filtered_data_title))
# Out:
# 870
# 870

# %%
client= OpenAI()
response = client.embeddings.create(
    input= filtered_data_title,
    model="text-embedding-3-small"
)

# %%
response.data[0].embedding
# Out:
# Embedding(embedding=[-0.00019478797912597656, 0.00707244873046875, -0.03106689453125, 0.068115234375, -0.01290130615234375, -0.0694580078125, -0.00514984130859375, 0.027435302734375, 0.0306243896484375, -0.037078857421875, -0.0036106109619140625, 0.0211334228515625, -0.04083251953125, 0.030975341796875, -0.0010881423950195312, 0.005947113037109375, 0.0194549560546875, 0.021453857421875, -0.0236968994140625, 0.01114654541015625, -0.04058837890625, 0.0211181640625, 0.03680419921875, -0.0228729248046875, -0.00750732421875, 0.0190887451171875, -0.01036834716796875, 0.031402587890625, 0.02020263671875, 0.054962158203125, -0.0293731689453125, -0.028656005859375, 0.0166473388671875, -0.03662109375, 0.0019216537475585938, -0.02020263671875, -0.005535125732421875, -0.0291748046875, 0.004302978515625, 0.031402587890625, 0.03466796875, 0.015350341796875, -0.0050811767578125, -0.03204345703125, 0.0401611328125, 0.044464111328125, -0.005939483642578125, 0.01702880859375, 0.00047707557678222656, 0.01212310791015625, 0.00870513916015625, 0.030120849609375, -0.01076507568359375, 0.06500244140625, -0.042999267578125, 0.002010345458984375, -0.003040313720703125, -0.00982666015625, -0.044342041015625, 0.0027027130126953125, 0.04180908203125, 0.05596923828125, -0.0078887939453125, -0.059295654296875, -0.02313232421875, -0.027435302734375, -0.003574371337890625, 0.0141143798828125, 0.034942626953125, -0.00673675537109375, -0.01181793212890625, 0.0419921875, 0.059967041015625, 0.0222320556640625, -0.0181121826171875, 0.0374755859375, -0.0016803741455078125, 0.043792724609375, -0.0509033203125, 0.00829315185546875, -0.034698486328125, 0.025909423828125, -0.0014982223510742188, 0.01354217529296875, -0.0274658203125, 0.0268096923828125, -0.014373779296875, -0.008056640625, -0.0016088485717773438, 0.018280029296875, -0.019500732421875, 0.037078857421875, 0.00714111328125, -0.022369384765625, -0.05224609375, -0.03912353515625, 0.0032711029052734375, -0.032867431640625, 0.054534912109375, 0.038177490234375, 0.0133056640625, -0.0022563934326171875, 0.01120758056640625, 0.025543212890625, 0.0435791015625, 0.01222991943359375, -0.019073486328125, -0.0271759033203125, -0.00618743896484375, -0.0220794677734375, 0.0560302734375, -0.0266265869140625, -0.037933349609375, 0.00431060791015625, -0.0243377685546875, -0.03656005859375, 0.01287078857421875, -0.0147705078125, -0.016510009765625, 0.00882720947265625, -0.0297088623046875, -0.0161285400390625, -0.038177490234375, -0.0174102783203125, 0.028106689453125, 0.00595855712890625, -0.042266845703125, 0.021759033203125, -0.006107330322265625, -0.07269287109375, 0.004878997802734375, 0.049224853515625, -0.005138397216796875, -0.03338623046875, -0.038543701171875, 0.0005588531494140625, 0.01264190673828125, 0.0085601806640625, 0.05279541015625, 0.0098724365234375, 0.0009765625, 0.0283660888671875, -0.0550537109375, -0.01451873779296875, -0.05584716796875, -0.001415252685546875, -0.0076141357421875, -0.0460205078125, 0.02734375, 0.023651123046875, -0.0452880859375, 0.025848388671875, 0.023529052734375, 0.06365966796875, -0.045013427734375, -0.0261383056640625, -0.0014257431030273438, 0.0474853515625, -0.0073089599609375, -0.007598876953125, 0.0302581787109375, -0.0004496574401855469, 0.0120849609375, 0.03387451171875, 0.04803466796875, 0.053009033203125, 0.049041748046875, -0.022247314453125, -0.02008056640625, -0.0075531005859375, -0.0005145072937011719, 0.0111846923828125, 0.003574371337890625, -0.0394287109375, -0.0227508544921875, 0.018341064453125, 0.05621337890625, 0.0003066062927246094, 0.0248260498046875, -0.03997802734375, -0.0400390625, 0.04534912109375, 0.03863525390625, -0.0012388229370117188, 0.01122283935546875, -0.016754150390625, 0.0113067626953125, -5.269050598144531e-05, 0.00923919677734375, -0.03155517578125, -0.0011625289916992188, -0.0194091796875, -0.00861358642578125, 0.0028667449951171875, -0.02032470703125, -0.018463134765625, 0.004985809326171875, 0.02569580078125, 0.01293182373046875, -0.01 ...

# %%
dataset_guid_embed=[]
dataset_embedding=[]
for i in range(0,len(filtered_data_title)):
    dataset_guid_embed.append(dataset[i]['guid'])
    dataset_embedding.append(response.data[i].embedding)

# %%
import numpy as np

# %%
np.savez_compressed(
    "dataset_embedding.npz",
    guids=np.array(dataset_guid_embed),
    embeddings=np.array(dataset_embedding)
)

# %%
query="What is happening with Patriot missile support for Ukraine?"

# %%
from openai import OpenAI
client= OpenAI()
import numpy as np

# %%
response = client.embeddings.create(
    input=query,
    model="text-embedding-3-small"
)

# %%
data = np.load("dataset_embedding.npz")

# %%
data['guids'][0]
# Out:
# np.str_('e3dc5caa18f9a16d7edcc09f8d5c2bb4')

# %%
query_embedding=response.data[0].embedding

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(
    [query_embedding],
    data['embeddings']
)[0]

# %%
similarity = enumerate(similarity)

# %%
similarity= sorted(similarity,key=lambda x:x[1],reverse=True)

# %%
result=[]
for i in range(0,5):
    index,probability = similarity[i]
    print(index)
    print(probability)
    result.append(data['guids'][index])
